# %% [markdown]
# # KMST Verdict Decisions Downloader
#
# This notebook downloads and processes Korean Maritime Safety Tribunal (KMST) verdict decisions. It performs the following tasks:
#
# 1. Loads a CSV file containing vessel names and URLs
# 2. Downloads verdict decision files from the provided URLs
# 3. Renames the downloaded files based on vessel names
# 4. Handles duplicate filenames and error cases
#
# The notebook uses pandas for data handling and the requests library for downloading files.

# %%
import pandas as pd
import os
import requests
from pathlib import Path
import logging
from datetime import datetime

# %%
decisions_df = pd.read_csv('../data/extracted_vessel_names.csv')

# %%
def download_and_rename_decisions(df, output_dir='downloaded_decisions'):
    """
    Downloads decision files and renames them based on vessel names
    
    Args:
        df: DataFrame containing 'url' and 'vessel_name' columns
        output_dir: Directory to save downloaded files
    """
    # Create output directory if it doesn't exist
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    # Track existing filenames to handle duplicates
    existing_names = set()
    
    for idx, row in df.iterrows():
        try:
            # Get the URL and vessel names
            url = row['url']
            vessel_names = row['vessel_name']
            
            # Convert string representation of list to actual list if needed
            if isinstance(vessel_names, str):
                try:
                    # Handle string representation of list
                    vessel_names = eval(vessel_names)
                except:
                    # If it's a single vessel name, make it a list
                    vessel_names = [vessel_names]
            elif not isinstance(vessel_names, list):
                vessel_names = [str(vessel_names)]
                
            # Create filename from vessel names
            base_filename = '-'.join(vessel_names)
            filename = base_filename
            
            # Handle duplicate filenames
            counter = 1
            while filename in existing_names:
                filename = f"{base_filename}-{counter}"
                counter += 1
            
            existing_names.add(filename)
            
            print(f"Downloading {filename} from {url}")  # Add debug print
            
            # Download the file
            response = requests.get(url, timeout=30)
            response.raise_for_status()
            
            # Save the file with .hwpextension
            output_path = os.path.join(output_dir, f"{filename}.hwp")
            with open(output_path, 'wb') as f:
                f.write(response.content)
                
            print(f"Successfully downloaded: {filename}")
            
        except Exception as e:
            error_msg = f"Error processing row {idx}: {str(e)}"
            print(error_msg)
            logging.error(error_msg)
            continue

# %%
# Set up logging
log_filename = f'download_errors_{datetime.now().strftime("%Y%m%d_%H%M%S")}.log'
logging.basicConfig(filename=log_filename, level=logging.ERROR,
                   format='%(asctime)s - %(message)s')

# %%
# Execute the download function
download_and_rename_decisions(decisions_df)
# Out:
# Downloading Myungyoonho-Daeyangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100553&fileSn=1
# Successfully downloaded: Myungyoonho-Daeyangho
# Downloading Geumoh 7-Woogukti 5 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100499&fileSn=1
# Successfully downloaded: Geumoh 7-Woogukti 5
# Downloading 26 Namseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100496&fileSn=1
# Successfully downloaded: 26 Namseongho
# Downloading Gwangjeong 8-Gwangjeong 88 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100493&fileSn=1
# Successfully downloaded: Gwangjeong 8-Gwangjeong 88
# Downloading Yeonheungho 2007-Sing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100447&fileSn=1
# Successfully downloaded: Yeonheungho 2007-Sing
# Downloading 101 Tongyeongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100444&fileSn=1
# Successfully downloaded: 101 Tongyeongho
# Downloading Seong-ho-cargo from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100441&fileSn=1
# Successfully downloaded: Seong-ho-cargo
# Downloading Stella from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100195&fileSn=1
# Successfully downloaded: Stella
# Downloading  from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100267&fileSn=1
# Successfully downloaded:
# Downloading Palpalho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100186&fileSn=1
# Successfully downloaded: Palpalho
# Downloading Dongjinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100201&fileSn=1
# Successfully downloaded: Dongjinho
# Downloading Oil-liquid from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100216&fileSn=1
# Successfully downloaded: Oil-liquid
# Downloading Seomsarang from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100435&fileSn=1
# Successfully downloaded: Seomsarang
# Downloading Hyundai-ho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100432&fileSn=1
# Successfully downloaded: Hyundai-ho-fishing
# Downloading oil from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100409&fileSn=1
# Successfully downloaded: oil
# Downloading Sinoglory from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100430&fileSn=1
# Successfully downloaded: Sinoglory
# Downloading Southern from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100351&fileSn=1
# Successfully downloaded: Southern
# Downloading Maeilho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100490&fileSn=1
# Successfully downloaded: Maeilho
# Downloading Wonchangho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100400&fileSn=1
# Successfully downloaded: Wonchangho-fishing
# Downloading Hope-ho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100330&fileSn=1
# Successfully downloaded: Hope-ho
# Downloading Ppeuriho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100326&fileSn=1
# Successfully downloaded: Ppeuriho
# Downloading Hakata from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100174&fileSn=1
# Successfully downloaded: Hakata
# Downloading Cheon from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100204&fileSn=1
# Successfully downloaded: Cheon
# Downloading 809 Joo from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100335&fileSn=1
# Successfully downloaded: 809 Joo
# Downloading Mangeumho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100320&fileSn=1
# Successfully downloaded: Mangeumho
# Downloading Giheungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100255&fileSn=1
# Successfully downloaded: Giheungho
# Downloading 105 Daejinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100252&fileSn=1
# Successfully downloaded: 105 Daejinho
# Downloading Pyeongan 2 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100291&fileSn=1
# Successfully downloaded: Pyeongan 2
# Downloading Haeanho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100289&fileSn=1
# Successfully downloaded: Haeanho
# Downloading Monster-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100450&fileSn=1
# Successfully downloaded: Monster-fishing
# Downloading Changwonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100438&fileSn=1
# Successfully downloaded: Changwonho
# Downloading 85 capsizes from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79110&fileSn=1
# Successfully downloaded: 85 capsizes
# Downloading 203 Daeseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79109&fileSn=1
# Successfully downloaded: 203 Daeseongho
# Downloading Red from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79104&fileSn=1
# Successfully downloaded: Red
# Downloading Minseong 1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79101&fileSn=1
# Successfully downloaded: Minseong 1
# Downloading KMTC from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79098&fileSn=1
# Successfully downloaded: KMTC
# Downloading Nuriho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79097&fileSn=1
# Successfully downloaded: Nuriho
# Downloading 118 Geumseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79093&fileSn=1
# Successfully downloaded: 118 Geumseongho
# Downloading Dolphin from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79089&fileSn=1
# Successfully downloaded: Dolphin
# Downloading -1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79086&fileSn=1
# Successfully downloaded: -1
# Downloading Jinheungho-Chansungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79085&fileSn=1
# Successfully downloaded: Jinheungho-Chansungho
# Downloading Yang-ho-towed-Geonmin 17000-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79082&fileSn=1
# Successfully downloaded: Yang-ho-towed-Geonmin 17000-fishing
# Downloading Sejongho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79077&fileSn=1
# Successfully downloaded: Sejongho-fishing
# Downloading Garamho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79076&fileSn=1
# Successfully downloaded: Garamho
# Downloading daegwangho-Yeongchangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79071&fileSn=1
# Successfully downloaded: daegwangho-Yeongchangho
# Downloading Cheonggwangho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79068&fileSn=1
# Successfully downloaded: Cheonggwangho-fishing
# Downloading -2 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79066&fileSn=1
# Successfully downloaded: -2
# Downloading Legend-ho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79063&fileSn=1
# Successfully downloaded: Legend-ho-fishing
# Downloading Mugunghwa 14-Fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79059&fileSn=1
# Successfully downloaded: Mugunghwa 14-Fishing
# Downloading Partner-auxiliary from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79058&fileSn=1
# Successfully downloaded: Partner-auxiliary
# Downloading Shinaho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79053&fileSn=1
# Successfully downloaded: Shinaho
# Downloading Nike from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79051&fileSn=1
# Successfully downloaded: Nike
# Downloading Sejinho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79047&fileSn=1
# Successfully downloaded: Sejinho-fishing
# Downloading Yudongho-Yudong from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79046&fileSn=1
# Successfully downloaded: Yudongho-Yudong
# Downloading -3 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79041&fileSn=1
# Successfully downloaded: -3
# Downloading Dong-A-T 3 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79039&fileSn=1
# Successfully downloaded: Dong-A-T 3
# Downloading Shin from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79036&fileSn=1
# Successfully downloaded: Shin
# Downloading Daeshinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79033&fileSn=1
# Successfully downloaded: Daeshinho
# Downloading -4 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79031&fileSn=1
# Successfully downloaded: -4
# Downloading Geumsin 101 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79028&fileSn=1
# Successfully downloaded: Geumsin 101
# Downloading Daeilho-bulk from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79025&fileSn=1
# Successfully downloaded: Daeilho-bulk
# Downloading -5 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79022&fileSn=1
# Successfully downloaded: -5
# Downloading Xiangxuelan from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79017&fileSn=1
# Successfully downloaded: Xiangxuelan
# Downloading Shinyoung 51 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79014&fileSn=1
# Successfully downloaded: Shinyoung 51
# Downloading patrol from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79011&fileSn=1
# Successfully downloaded: patrol
# Downloading Gukhanho-Johyeonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79008&fileSn=1
# Successfully downloaded: Gukhanho-Johyeonho
# Downloading Daemyungho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79005&fileSn=1
# Successfully downloaded: Daemyungho-fishing
# Downloading Haeseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79004&fileSn=1
# Successfully downloaded: Haeseongho
# Downloading Champion-ho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=79001&fileSn=1
# Successfully downloaded: Champion-ho
# Downloading Seon from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78997&fileSn=1
# Successfully downloaded: Seon
# Downloading -6 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78993&fileSn=1
# Successfully downloaded: -6
# Downloading Jeongwonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78990&fileSn=1
# Successfully downloaded: Jeongwonho
# Downloading 77 Taekwangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78987&fileSn=1
# Successfully downloaded: 77 Taekwangho
# Downloading Mipo 8001-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78986&fileSn=1
# Successfully downloaded: Mipo 8001-fishing
# Downloading -7 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78981&fileSn=1
# Successfully downloaded: -7
# Downloading Yeosu from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78980&fileSn=1
# Successfully downloaded: Yeosu
# Downloading 201 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78977&fileSn=1
# Successfully downloaded: 201
# Downloading Seonghyeonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78974&fileSn=1
# Successfully downloaded: Seonghyeonho
# Downloading Triton-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78970&fileSn=1
# Successfully downloaded: Triton-fishing
# Downloading 1 Good from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78968&fileSn=1
# Successfully downloaded: 1 Good
# Downloading Changgilho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78965&fileSn=1
# Successfully downloaded: Changgilho-fishing
# Downloading Haeseongho-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100818&fileSn=1
# Successfully downloaded: Haeseongho-1
# Downloading Moa from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78959&fileSn=1
# Successfully downloaded: Moa
# Downloading Rim from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78955&fileSn=1
# Successfully downloaded: Rim
# Downloading Je from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78952&fileSn=1
# Successfully downloaded: Je
# Downloading Jungwonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78950&fileSn=1
# Successfully downloaded: Jungwonho
# Downloading Gangnamho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78945&fileSn=1
# Successfully downloaded: Gangnamho-fishing
# Downloading Eojinho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78944&fileSn=1
# Successfully downloaded: Eojinho-fishing
# Downloading Je-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78941&fileSn=1
# Successfully downloaded: Je-1
# Downloading Eun from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78936&fileSn=1
# Successfully downloaded: Eun
# Downloading Daewonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78933&fileSn=1
# Successfully downloaded: Daewonho
# Downloading Hwanggeumho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78932&fileSn=1
# Successfully downloaded: Hwanggeumho
# Downloading Deokjinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78929&fileSn=1
# Successfully downloaded: Deokjinho
# Downloading Hanaho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78926&fileSn=1
# Successfully downloaded: Hanaho
# Downloading 85 Daeyangho-New from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78921&fileSn=1
# Successfully downloaded: 85 Daeyangho-New
# Downloading Xinweijinxiang from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78918&fileSn=1
# Successfully downloaded: Xinweijinxiang
# Downloading Myeongilho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78916&fileSn=1
# Successfully downloaded: Myeongilho
# Downloading 66 Pungseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78912&fileSn=1
# Successfully downloaded: 66 Pungseongho
# Downloading 2003 Shinsungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78909&fileSn=1
# Successfully downloaded: 2003 Shinsungho
# Downloading Ocean-Tongsun 7 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78907&fileSn=1
# Successfully downloaded: Ocean-Tongsun 7
# Downloading 305 Gyeongseonho-Stolt from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78905&fileSn=1
# Successfully downloaded: 305 Gyeongseonho-Stolt
# Downloading Blue from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78900&fileSn=1
# Successfully downloaded: Blue
# Downloading Geon-ho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78898&fileSn=1
# Successfully downloaded: Geon-ho-fishing
# Downloading Dongjinho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78894&fileSn=1
# Successfully downloaded: Dongjinho-fishing
# Downloading Apollo from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78891&fileSn=1
# Successfully downloaded: Apollo
# Downloading Dongseongho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78888&fileSn=1
# Successfully downloaded: Dongseongho-fishing
# Downloading Jongjinho-206 Changshinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78886&fileSn=1
# Successfully downloaded: Jongjinho-206 Changshinho
# Downloading Sampyo 38 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78882&fileSn=1
# Successfully downloaded: Sampyo 38
# Downloading Family-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78881&fileSn=1
# Successfully downloaded: Family-fishing
# Downloading New from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78878&fileSn=1
# Successfully downloaded: New
# Downloading Jeonjaho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78875&fileSn=1
# Successfully downloaded: Jeonjaho
# Downloading -8 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=78870&fileSn=1
# Successfully downloaded: -8
# Downloading Stella-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100284&fileSn=1
# Successfully downloaded: Stella-1
# Downloading Cheongryongho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100270&fileSn=1
# Successfully downloaded: Cheongryongho-fishing
# Downloading Je-2 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100225&fileSn=1
# Successfully downloaded: Je-2
# Downloading Seonggwangho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100323&fileSn=1
# Successfully downloaded: Seonggwangho-fishing
# Downloading Binho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100293&fileSn=1
# Successfully downloaded: Binho-fishing
# Downloading 365 green from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100472&fileSn=1
# Successfully downloaded: 365 green
# Downloading Uriho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100593&fileSn=1
# Successfully downloaded: Uriho-fishing
# Downloading 203 Wonchangho-Je from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100555&fileSn=1
# Successfully downloaded: 203 Wonchangho-Je
# Downloading Neptune from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100341&fileSn=1
# Successfully downloaded: Neptune
# Downloading Milano from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100311&fileSn=1
# Successfully downloaded: Milano
# Downloading Je-3 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100234&fileSn=1
# Successfully downloaded: Je-3
# Downloading Master-Cheonghaeho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100276&fileSn=1
# Successfully downloaded: Master-Cheonghaeho
# Downloading Lounge from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100487&fileSn=1
# Successfully downloaded: Lounge
# Downloading 306 Min from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100457&fileSn=1
# Successfully downloaded: 306 Min
# Downloading Geonyangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100379&fileSn=1
# Successfully downloaded: Geonyangho
# Downloading Daemyung 11 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100427&fileSn=1
# Successfully downloaded: Daemyung 11
# Downloading -9 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100388&fileSn=1
# Successfully downloaded: -9
# Downloading Gwangyeongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100523&fileSn=1
# Successfully downloaded: Gwangyeongho
# Downloading Suhyeonho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100502&fileSn=1
# Successfully downloaded: Suhyeonho-fishing
# Downloading Sistar 11 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100484&fileSn=1
# Successfully downloaded: Sistar 11
# Downloading CNP from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100415&fileSn=1
# Successfully downloaded: CNP
# Downloading Yeongshinho-sea from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100394&fileSn=1
# Successfully downloaded: Yeongshinho-sea
# Downloading Geumgang from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100391&fileSn=1
# Successfully downloaded: Geumgang
# Downloading Star from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100367&fileSn=1
# Successfully downloaded: Star
# Downloading Bogwang from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100364&fileSn=1
# Successfully downloaded: Bogwang
# Downloading Seongho-refrigerated from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81909&fileSn=1
# Successfully downloaded: Seongho-refrigerated
# Downloading Fishing-ho-Fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81903&fileSn=1
# Successfully downloaded: Fishing-ho-Fishing
# Downloading Hwasungho-New from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81900&fileSn=1
# Successfully downloaded: Hwasungho-New
# Downloading -10 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81897&fileSn=1
# Successfully downloaded: -10
# Downloading Namseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81896&fileSn=1
# Successfully downloaded: Namseongho
# Downloading Navig 8 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81892&fileSn=1
# Successfully downloaded: Navig 8
# Downloading Stellaho-Dongseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=67447&fileSn=1
# Successfully downloaded: Stellaho-Dongseongho
# Downloading No from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91624&fileSn=1
# Successfully downloaded: No
# Downloading -11 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=71040&fileSn=1
# Successfully downloaded: -11
# Downloading Susungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81881&fileSn=1
# Successfully downloaded: Susungho
# Downloading Laon-ho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81876&fileSn=1
# Successfully downloaded: Laon-ho-fishing
# Downloading Golden from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81875&fileSn=1
# Successfully downloaded: Golden
# Downloading -12 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81857&fileSn=1
# Successfully downloaded: -12
# Downloading Starex from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81854&fileSn=1
# Successfully downloaded: Starex
# Downloading Dong-A from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81870&fileSn=1
# Successfully downloaded: Dong-A
# Downloading -13 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81869&fileSn=1
# Successfully downloaded: -13
# Downloading Yang-ho-towed-Haegwang 5005-general from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81865&fileSn=1
# Successfully downloaded: Yang-ho-towed-Haegwang 5005-general
# Downloading Gwangyangho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81862&fileSn=1
# Successfully downloaded: Gwangyangho-fishing
# Downloading Donggeobukho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81859&fileSn=1
# Successfully downloaded: Donggeobukho-fishing
# Downloading Jin-ho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81849&fileSn=1
# Successfully downloaded: Jin-ho-fishing
# Downloading Hanyu-Tasco from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81846&fileSn=1
# Successfully downloaded: Hanyu-Tasco
# Downloading Frontier-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81845&fileSn=1
# Successfully downloaded: Frontier-fishing
# Downloading Jaeyoung 77-Seonjin 13 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81840&fileSn=1
# Successfully downloaded: Jaeyoung 77-Seonjin 13
# Downloading 301 Shinhangmanho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81837&fileSn=1
# Successfully downloaded: 301 Shinhangmanho
# Downloading Guidance-Inspection from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81836&fileSn=1
# Successfully downloaded: Guidance-Inspection
# Downloading Hanlim-9 and-Minhoho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=81833&fileSn=1
# Successfully downloaded: Hanlim-9 and-Minhoho
# Downloading 11 stranding from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100177&fileSn=1
# Successfully downloaded: 11 stranding
# Downloading 21 Gilseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100222&fileSn=1
# Successfully downloaded: 21 Gilseongho
# Downloading Jjanggu from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100180&fileSn=1
# Successfully downloaded: Jjanggu
# Downloading Orange-Poseidon from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100168&fileSn=1
# Successfully downloaded: Orange-Poseidon
# Downloading Jiyoungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100345&fileSn=1
# Successfully downloaded: Jiyoungho
# Downloading Dae-yong-car from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100299&fileSn=1
# Successfully downloaded: Dae-yong-car
# Downloading 72 Haeyoungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100273&fileSn=1
# Successfully downloaded: 72 Haeyoungho
# Downloading 13 Ocean-207 Yun from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100264&fileSn=1
# Successfully downloaded: 13 Ocean-207 Yun
# Downloading Jinstaho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100261&fileSn=1
# Successfully downloaded: Jinstaho
# Downloading Eunseongho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100249&fileSn=1
# Successfully downloaded: Eunseongho-fishing
# Downloading Seongjinho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100591&fileSn=1
# Successfully downloaded: Seongjinho-fishing
# Downloading Daebokho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100382&fileSn=1
# Successfully downloaded: Daebokho-fishing
# Downloading Geumseong-ho-general from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100508&fileSn=1
# Successfully downloaded: Geumseong-ho-general
# Downloading -14 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100505&fileSn=1
# Successfully downloaded: -14
# Downloading Jeokbongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100424&fileSn=1
# Successfully downloaded: Jeokbongho
# Downloading Yeonchangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100421&fileSn=1
# Successfully downloaded: Yeonchangho
# Downloading Qingdao from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100385&fileSn=1
# Successfully downloaded: Qingdao
# Downloading Eunseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101153&fileSn=1
# Successfully downloaded: Eunseongho
# Downloading Globalho-Oceanho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100551&fileSn=1
# Successfully downloaded: Globalho-Oceanho
# Downloading Woosungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100547&fileSn=1
# Successfully downloaded: Woosungho
# Downloading Zenith from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100376&fileSn=1
# Successfully downloaded: Zenith
# Downloading 809 Joo-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100228&fileSn=1
# Successfully downloaded: 809 Joo-1
# Downloading Sajo from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100354&fileSn=1
# Successfully downloaded: Sajo
# Downloading 219 Shinheungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91818&fileSn=1
# Successfully downloaded: 219 Shinheungho
# Downloading 2020 Anseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91813&fileSn=1
# Successfully downloaded: 2020 Anseongho
# Downloading Seo from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91810&fileSn=1
# Successfully downloaded: Seo
# Downloading Seomsarang-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91809&fileSn=1
# Successfully downloaded: Seomsarang-1
# Downloading Seomsarang-2 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91804&fileSn=1
# Successfully downloaded: Seomsarang-2
# Downloading -15 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91803&fileSn=1
# Successfully downloaded: -15
# Downloading -16 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91800&fileSn=1
# Successfully downloaded: -16
# Downloading Haegeumho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91797&fileSn=1
# Successfully downloaded: Haegeumho
# Downloading Deokmyeongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91792&fileSn=1
# Successfully downloaded: Deokmyeongho
# Downloading Pyeong-eun from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91790&fileSn=1
# Successfully downloaded: Pyeong-eun
# Downloading Hanbadaho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91786&fileSn=1
# Successfully downloaded: Hanbadaho
# Downloading Cargo-cafe from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91783&fileSn=1
# Successfully downloaded: Cargo-cafe
# Downloading Seomdribigum-Engine from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91782&fileSn=1
# Successfully downloaded: Seomdribigum-Engine
# Downloading Island from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91777&fileSn=1
# Successfully downloaded: Island
# Downloading Monsterho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91775&fileSn=1
# Successfully downloaded: Monsterho-fishing
# Downloading Jeju-Coast from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91771&fileSn=1
# Successfully downloaded: Jeju-Coast
# Downloading -17 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91768&fileSn=1
# Successfully downloaded: -17
# Downloading Asungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91765&fileSn=1
# Successfully downloaded: Asungho
# Downloading Hyosungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91763&fileSn=1
# Successfully downloaded: Hyosungho
# Downloading Cheonghaeho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91760&fileSn=1
# Successfully downloaded: Cheonghaeho-fishing
# Downloading 1 Dongyangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91756&fileSn=1
# Successfully downloaded: 1 Dongyangho
# Downloading Sudeokho-Yeonggwangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91753&fileSn=1
# Successfully downloaded: Sudeokho-Yeonggwangho
# Downloading Dream from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91750&fileSn=1
# Successfully downloaded: Dream
# Downloading Large-3 Engine from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91747&fileSn=1
# Successfully downloaded: Large-3 Engine
# Downloading 207 Haeseonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91744&fileSn=1
# Successfully downloaded: 207 Haeseonho
# Downloading Haedongho-bulk from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91741&fileSn=1
# Successfully downloaded: Haedongho-bulk
# Downloading Bigeum from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91738&fileSn=1
# Successfully downloaded: Bigeum
# Downloading 89 Bogwangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91735&fileSn=1
# Successfully downloaded: 89 Bogwangho
# Downloading Laonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91734&fileSn=1
# Successfully downloaded: Laonho
# Downloading Seo-on-ho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91729&fileSn=1
# Successfully downloaded: Seo-on-ho
# Downloading Yongjin from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91726&fileSn=1
# Successfully downloaded: Yongjin
# Downloading Dong-jin-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91723&fileSn=1
# Successfully downloaded: Dong-jin-fishing
# Downloading Daegumho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91722&fileSn=1
# Successfully downloaded: Daegumho
# Downloading Geonyeongho-Asiaho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91719&fileSn=1
# Successfully downloaded: Geonyeongho-Asiaho
# Downloading 307 Sangjinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91714&fileSn=1
# Successfully downloaded: 307 Sangjinho
# Downloading Yeongjinho-Jeongyunho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91711&fileSn=1
# Successfully downloaded: Yeongjinho-Jeongyunho
# Downloading Sejongho-Sujinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91709&fileSn=1
# Successfully downloaded: Sejongho-Sujinho
# Downloading Hwaseungho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91705&fileSn=1
# Successfully downloaded: Hwaseungho-fishing
# Downloading -18 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91702&fileSn=1
# Successfully downloaded: -18
# Downloading Manbokho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91700&fileSn=1
# Successfully downloaded: Manbokho
# Downloading 9009 Gyeongjinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91698&fileSn=1
# Successfully downloaded: 9009 Gyeongjinho
# Downloading -19 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91693&fileSn=1
# Successfully downloaded: -19
# Downloading Ilhyeonjeongho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91690&fileSn=1
# Successfully downloaded: Ilhyeonjeongho-fishing
# Downloading Stella-2 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91688&fileSn=1
# Successfully downloaded: Stella-2
# Downloading 237 Yang from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91684&fileSn=1
# Successfully downloaded: 237 Yang
# Downloading Haesongho-towed from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91683&fileSn=1
# Successfully downloaded: Haesongho-towed
# Downloading -20 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91680&fileSn=1
# Successfully downloaded: -20
# Downloading 212 Seongjiho-Yonggungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91677&fileSn=1
# Successfully downloaded: 212 Seongjiho-Yonggungho
# Downloading 307 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91673&fileSn=1
# Successfully downloaded: 307
# Downloading Lounge-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91671&fileSn=1
# Successfully downloaded: Lounge-1
# Downloading 309 Buyeongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91666&fileSn=1
# Successfully downloaded: 309 Buyeongho
# Downloading Manseokho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91664&fileSn=1
# Successfully downloaded: Manseokho-fishing
# Downloading Bokyunho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91660&fileSn=1
# Successfully downloaded: Bokyunho
# Downloading Yongseongho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91657&fileSn=1
# Successfully downloaded: Yongseongho-fishing
# Downloading 103 Subokho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91654&fileSn=1
# Successfully downloaded: 103 Subokho
# Downloading Namseongho-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91653&fileSn=1
# Successfully downloaded: Namseongho-1
# Downloading 201 Dongseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91648&fileSn=1
# Successfully downloaded: 201 Dongseongho
# Downloading 306 Min-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91645&fileSn=1
# Successfully downloaded: 306 Min-1
# Downloading 78 Im from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91644&fileSn=1
# Successfully downloaded: 78 Im
# Downloading Fishing-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91641&fileSn=1
# Successfully downloaded: Fishing-fishing
# Downloading Ark from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91638&fileSn=1
# Successfully downloaded: Ark
# Downloading 603 Jo from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91633&fileSn=1
# Successfully downloaded: 603 Jo
# Downloading Bokho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91632&fileSn=1
# Successfully downloaded: Bokho-fishing
# Downloading Daecheongho-Gyeongdeokho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91627&fileSn=1
# Successfully downloaded: Daecheongho-Gyeongdeokho
# Downloading Gwanghaeho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91622&fileSn=1
# Successfully downloaded: Gwanghaeho
# Downloading Jinjoho-Sudongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91618&fileSn=1
# Successfully downloaded: Jinjoho-Sudongho
# Downloading 107 Subokho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91616&fileSn=1
# Successfully downloaded: 107 Subokho
# Downloading Taejinho-Gipungeo 00188 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91612&fileSn=1
# Successfully downloaded: Taejinho-Gipungeo 00188
# Downloading Daehanho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91611&fileSn=1
# Successfully downloaded: Daehanho
# Downloading Pishingho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91606&fileSn=1
# Successfully downloaded: Pishingho-fishing
# Downloading Dalma 3 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91603&fileSn=1
# Successfully downloaded: Dalma 3
# Downloading 207 Seongjinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91601&fileSn=1
# Successfully downloaded: 207 Seongjinho
# Downloading 2015 Yeonghyo from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91598&fileSn=1
# Successfully downloaded: 2015 Yeonghyo
# Downloading Seyoung from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91594&fileSn=1
# Successfully downloaded: Seyoung
# Downloading Donggwangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91592&fileSn=1
# Successfully downloaded: Donggwangho
# Downloading Taeyangho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91588&fileSn=1
# Successfully downloaded: Taeyangho-fishing
# Downloading Bodyguard from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91585&fileSn=1
# Successfully downloaded: Bodyguard
# Downloading 2017 Yeongilho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91582&fileSn=1
# Successfully downloaded: 2017 Yeongilho
# Downloading New-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91580&fileSn=1
# Successfully downloaded: New-1
# Downloading Sewonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91578&fileSn=1
# Successfully downloaded: Sewonho
# Downloading 507 Shinheungho-Haenam from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91575&fileSn=1
# Successfully downloaded: 507 Shinheungho-Haenam
# Downloading Je-4 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91570&fileSn=1
# Successfully downloaded: Je-4
# Downloading Arion-Seju from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91567&fileSn=1
# Successfully downloaded: Arion-Seju
# Downloading Daeseongho-Samyeop 1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91564&fileSn=1
# Successfully downloaded: Daeseongho-Samyeop 1
# Downloading 82 Boseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91562&fileSn=1
# Successfully downloaded: 82 Boseongho
# Downloading Yeondeungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91560&fileSn=1
# Successfully downloaded: Yeondeungho
# Downloading Aero from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91555&fileSn=1
# Successfully downloaded: Aero
# Downloading -21 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91552&fileSn=1
# Successfully downloaded: -21
# Downloading Geoyoung from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91550&fileSn=1
# Successfully downloaded: Geoyoung
# Downloading 203 Hyeonjinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91546&fileSn=1
# Successfully downloaded: 203 Hyeonjinho
# Downloading 202 Hanilho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91543&fileSn=1
# Successfully downloaded: 202 Hanilho
# Downloading Je-5 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91542&fileSn=1
# Successfully downloaded: Je-5
# Downloading Jeongnamjin-Fishing-Ilshinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91539&fileSn=1
# Successfully downloaded: Jeongnamjin-Fishing-Ilshinho
# Downloading Yuseongho-Jaehyunho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91534&fileSn=1
# Successfully downloaded: Yuseongho-Jaehyunho
# Downloading 1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91531&fileSn=1
# Successfully downloaded: 1
# Downloading February from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91528&fileSn=1
# Successfully downloaded: February
# Downloading Black from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91525&fileSn=1
# Successfully downloaded: Black
# Downloading Jangguho-Hunterho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91524&fileSn=1
# Successfully downloaded: Jangguho-Hunterho
# Downloading Jinmyeongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91519&fileSn=1
# Successfully downloaded: Jinmyeongho
# Downloading Seogwangho-Daebogho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91518&fileSn=1
# Successfully downloaded: Seogwangho-Daebogho
# Downloading Leisure-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91515&fileSn=1
# Successfully downloaded: Leisure-fishing
# Downloading 300 Oh-Jin from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91510&fileSn=1
# Successfully downloaded: 300 Oh-Jin
# Downloading 103 Daeyangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91507&fileSn=1
# Successfully downloaded: 103 Daeyangho
# Downloading 2015 Yeonghyo-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91504&fileSn=1
# Successfully downloaded: 2015 Yeonghyo-1
# Downloading Heungyeongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91503&fileSn=1
# Successfully downloaded: Heungyeongho
# Downloading Je-6 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91498&fileSn=1
# Successfully downloaded: Je-6
# Downloading 2019 Myeongseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91495&fileSn=1
# Successfully downloaded: 2019 Myeongseongho
# Downloading 2013 Cheonghaeho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91493&fileSn=1
# Successfully downloaded: 2013 Cheonghaeho
# Downloading Donggeobukho-fishing-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91489&fileSn=1
# Successfully downloaded: Donggeobukho-fishing-1
# Downloading Yun-Nam from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91488&fileSn=1
# Successfully downloaded: Yun-Nam
# Downloading 102 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91483&fileSn=1
# Successfully downloaded: 102
# Downloading 1 Haejinho-Hwanggeumho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91480&fileSn=1
# Successfully downloaded: 1 Haejinho-Hwanggeumho
# Downloading 707 Haepungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91477&fileSn=1
# Successfully downloaded: 707 Haepungho
# Downloading Bogoho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91474&fileSn=1
# Successfully downloaded: Bogoho
# Downloading Biyangdocheonnyeonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91471&fileSn=1
# Successfully downloaded: Biyangdocheonnyeonho
# Downloading 2012 Black from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91468&fileSn=1
# Successfully downloaded: 2012 Black
# Downloading Mariner-watercraft from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91467&fileSn=1
# Successfully downloaded: Mariner-watercraft
# Downloading 33 Dongikho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100348&fileSn=1
# Successfully downloaded: 33 Dongikho
# Downloading Suyeongho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100258&fileSn=1
# Successfully downloaded: Suyeongho-fishing
# Downloading 97 Imsuho-Guipei from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100246&fileSn=1
# Successfully downloaded: 97 Imsuho-Guipei
# Downloading Light from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100198&fileSn=1
# Successfully downloaded: Light
# Downloading Yujoho-Haniho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100418&fileSn=1
# Successfully downloaded: Yujoho-Haniho
# Downloading Myeongseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100453&fileSn=1
# Successfully downloaded: Myeongseongho
# Downloading Geumhwa from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100357&fileSn=1
# Successfully downloaded: Geumhwa
# Downloading Sea-Cheolsanho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100397&fileSn=1
# Successfully downloaded: Sea-Cheolsanho
# Downloading 2020 Anseongho-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101395&fileSn=1
# Successfully downloaded: 2020 Anseongho-1
# Downloading Geumgangho-auxiliary from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101601&fileSn=1
# Successfully downloaded: Geumgangho-auxiliary
# Downloading Samunho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100878&fileSn=1
# Successfully downloaded: Samunho-fishing
# Downloading -22 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101733&fileSn=1
# Successfully downloaded: -22
# Downloading Cheonghaeho-fishing-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101731&fileSn=1
# Successfully downloaded: Cheonghaeho-fishing-1
# Downloading Oil-liquid-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101621&fileSn=1
# Successfully downloaded: Oil-liquid-1
# Downloading Je-7 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101061&fileSn=1
# Successfully downloaded: Je-7
# Downloading Gwangjin 107-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100929&fileSn=1
# Successfully downloaded: Gwangjin 107-fishing
# Downloading Gwangjin 107 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101615&fileSn=1
# Successfully downloaded: Gwangjin 107
# Downloading -23 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101188&fileSn=1
# Successfully downloaded: -23
# Downloading Namgwang 2-Jeil from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101021&fileSn=1
# Successfully downloaded: Namgwang 2-Jeil
# Downloading Haeuriho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101019&fileSn=1
# Successfully downloaded: Haeuriho-fishing
# Downloading Binho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101017&fileSn=1
# Successfully downloaded: Binho
# Downloading Donghaho-Gwangilho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101015&fileSn=1
# Successfully downloaded: Donghaho-Gwangilho
# Downloading Namgyeongho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100896&fileSn=1
# Successfully downloaded: Namgyeongho-fishing
# Downloading 153 Gangseong 5 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100893&fileSn=1
# Successfully downloaded: 153 Gangseong 5
# Downloading Kumho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100890&fileSn=1
# Successfully downloaded: Kumho
# Downloading 153 Gangseongho 5 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100887&fileSn=1
# Successfully downloaded: 153 Gangseongho 5
# Downloading for from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101595&fileSn=1
# Successfully downloaded: for
# Downloading 2019 Haram-fishing-Su-gwang-ho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100872&fileSn=1
# Successfully downloaded: 2019 Haram-fishing-Su-gwang-ho
# Downloading New-2 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100866&fileSn=1
# Successfully downloaded: New-2
# Downloading Daewonho-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=67625&fileSn=1
# Successfully downloaded: Daewonho-1
# Downloading Hanaho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=67622&fileSn=1
# Successfully downloaded: Hanaho-fishing
# Downloading Shin-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=67620&fileSn=1
# Successfully downloaded: Shin-1
# Downloading Hojinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=67618&fileSn=1
# Successfully downloaded: Hojinho
# Downloading Ace-oil from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=67615&fileSn=1
# Successfully downloaded: Ace-oil
# Downloading Yubinho-Daeyangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=67612&fileSn=1
# Successfully downloaded: Yubinho-Daeyangho
# Downloading 155 Heeyoungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=67607&fileSn=1
# Successfully downloaded: 155 Heeyoungho
# Downloading KTS from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=67604&fileSn=1
# Successfully downloaded: KTS
# ...
# Successfully downloaded: coastal
# Downloading Haeyangho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=71003&fileSn=1
# Successfully downloaded: Haeyangho-fishing
# Downloading Je-17 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=71000&fileSn=1
# Successfully downloaded: Je-17
# Downloading 207 Namyangho-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=70995&fileSn=1
# Successfully downloaded: 207 Namyangho-1
# Downloading Real from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101452&fileSn=1
# Successfully downloaded: Real
# Downloading Geunyangho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101450&fileSn=1
# Successfully downloaded: Geunyangho-fishing
# Downloading Saemangeumho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101408&fileSn=1
# Successfully downloaded: Saemangeumho
# Downloading -44 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101337&fileSn=1
# Successfully downloaded: -44
# Downloading Seong-ho-Hae from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101331&fileSn=1
# Successfully downloaded: Seong-ho-Hae
# Downloading Sea from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101310&fileSn=1
# Successfully downloaded: Sea
# Downloading Geumgwang-Manchangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101196&fileSn=1
# Successfully downloaded: Geumgwang-Manchangho
# Downloading -45 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101194&fileSn=1
# Successfully downloaded: -45
# Downloading Ulsan 109-towed-Ulsan 6003-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101162&fileSn=1
# Successfully downloaded: Ulsan 109-towed-Ulsan 6003-fishing
# Downloading Baejangho-Fishing-Challenge from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101079&fileSn=1
# Successfully downloaded: Baejangho-Fishing-Challenge
# Downloading 322 Gwangdeokho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101076&fileSn=1
# Successfully downloaded: 322 Gwangdeokho
# Downloading 103 Haegeumho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100978&fileSn=1
# Successfully downloaded: 103 Haegeumho
# Downloading 609 Cheon from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100975&fileSn=1
# Successfully downloaded: 609 Cheon
# Downloading Hong-Tien from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100824&fileSn=1
# Successfully downloaded: Hong-Tien
# Downloading 88 Kyungyoungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100624&fileSn=1
# Successfully downloaded: 88 Kyungyoungho
# Downloading Gyeongilho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101302&fileSn=1
# Successfully downloaded: Gyeongilho
# Downloading Sujeongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101052&fileSn=1
# Successfully downloaded: Sujeongho
# Downloading 101 Yuhan from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101049&fileSn=1
# Successfully downloaded: 101 Yuhan
# Downloading Pacific-Je- from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101046&fileSn=1
# Successfully downloaded: Pacific-Je-
# Downloading Hanil from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101043&fileSn=1
# Successfully downloaded: Hanil
# Downloading Yeongbokho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101040&fileSn=1
# Successfully downloaded: Yeongbokho-fishing
# Downloading passenger-Hanil-New from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101037&fileSn=1
# Successfully downloaded: passenger-Hanil-New
# Downloading Jeongbinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101034&fileSn=1
# Successfully downloaded: Jeongbinho
# Downloading 32 Minho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101031&fileSn=1
# Successfully downloaded: 32 Minho
# Downloading Gwangdeokho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101025&fileSn=1
# Successfully downloaded: Gwangdeokho-fishing
# Downloading 203 Nam from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101022&fileSn=1
# Successfully downloaded: 203 Nam
# Downloading 205 Yeonheungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101008&fileSn=1
# Successfully downloaded: 205 Yeonheungho
# Downloading -46 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100981&fileSn=1
# Successfully downloaded: -46
# Downloading Oil-liquid-5 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100830&fileSn=1
# Successfully downloaded: Oil-liquid-5
# Downloading 9 Minseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101005&fileSn=1
# Successfully downloaded: 9 Minseongho
# Downloading 203 Namhaeho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100899&fileSn=1
# Successfully downloaded: 203 Namhaeho
# Downloading Yeonggwangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100800&fileSn=1
# Successfully downloaded: Yeonggwangho
# Downloading Sampyo 301-Changseong from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100650&fileSn=1
# Successfully downloaded: Sampyo 301-Changseong
# Downloading 203 Daeyoungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100647&fileSn=1
# Successfully downloaded: 203 Daeyoungho
# Downloading Samyangho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101319&fileSn=1
# Successfully downloaded: Samyangho-fishing
# Downloading 7 Heungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101316&fileSn=1
# Successfully downloaded: 7 Heungho
# Downloading Aresho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101313&fileSn=1
# Successfully downloaded: Aresho-fishing
# Downloading Deokseong from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101305&fileSn=1
# Successfully downloaded: Deokseong
# Downloading oil-liquid from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101209&fileSn=1
# Successfully downloaded: oil-liquid
# Downloading 25 Minseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101111&fileSn=1
# Successfully downloaded: 25 Minseongho
# Downloading -47 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101108&fileSn=1
# Successfully downloaded: -47
# Downloading Sejuho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101105&fileSn=1
# Successfully downloaded: Sejuho
# Downloading 101 Hanjinho-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100639&fileSn=1
# Successfully downloaded: 101 Hanjinho-1
# Downloading -48 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100636&fileSn=1
# Successfully downloaded: -48
# Downloading Gilchangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100633&fileSn=1
# Successfully downloaded: Gilchangho
# Downloading Yun from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100630&fileSn=1
# Successfully downloaded: Yun
# Downloading Seongunho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100612&fileSn=1
# Successfully downloaded: Seongunho
# Downloading Pilot 2 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100621&fileSn=1
# Successfully downloaded: Pilot 2
# Downloading Shule from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91824&fileSn=1
# Successfully downloaded: Shule
# Downloading Byeokangho-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=91821&fileSn=1
# Successfully downloaded: Byeokangho-1
# Downloading Chemiho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101363&fileSn=1
# Successfully downloaded: Chemiho-fishing
# Downloading Jeongwonho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100658&fileSn=1
# Successfully downloaded: Jeongwonho-fishing
# Downloading Challenge from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100615&fileSn=1
# Successfully downloaded: Challenge
# Downloading 209 Geumyeongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100526&fileSn=1
# Successfully downloaded: 209 Geumyeongho
# Downloading Songgwang 2 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100370&fileSn=1
# Successfully downloaded: Songgwang 2
# Downloading Deokyeonho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100338&fileSn=1
# Successfully downloaded: Deokyeonho-fishing
# Downloading Jungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101699&fileSn=1
# Successfully downloaded: Jungho
# Downloading HW-319 Yongcheonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101697&fileSn=1
# Successfully downloaded: HW-319 Yongcheonho
# Downloading Gilyangho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101406&fileSn=1
# Successfully downloaded: Gilyangho-fishing
# Downloading Yongseongho-Beomilho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101401&fileSn=1
# Successfully downloaded: Yongseongho-Beomilho
# Downloading 123 ocean from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101375&fileSn=1
# Successfully downloaded: 123 ocean
# Downloading Venus 2 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101348&fileSn=1
# Successfully downloaded: Venus 2
# Downloading Heungseongho-Taeseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101350&fileSn=1
# Successfully downloaded: Heungseongho-Taeseongho
# Downloading Geumgangho-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101353&fileSn=1
# Successfully downloaded: Geumgangho-1
# Downloading Geumyeongho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101355&fileSn=1
# Successfully downloaded: Geumyeongho-fishing
# Downloading Gwangyeongho-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101296&fileSn=1
# Successfully downloaded: Gwangyeongho-1
# Downloading 607 Myeongseong-ho-Truwind from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101294&fileSn=1
# Successfully downloaded: 607 Myeongseong-ho-Truwind
# Downloading Sky from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101214&fileSn=1
# Successfully downloaded: Sky
# Downloading Oil-liquid-6 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101211&fileSn=1
# Successfully downloaded: Oil-liquid-6
# Downloading Segilho-fishing-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101217&fileSn=1
# Successfully downloaded: Segilho-fishing-1
# Downloading 5 Deokseungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101204&fileSn=1
# Successfully downloaded: 5 Deokseungho
# Downloading 33 Je-Swan from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101159&fileSn=1
# Successfully downloaded: 33 Je-Swan
# Downloading 5002 Seongbo-86 Pyeongjinho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101085&fileSn=1
# Successfully downloaded: 5002 Seongbo-86 Pyeongjinho
# Downloading Anjin 1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=101064&fileSn=1
# Successfully downloaded: Anjin 1
# Downloading Gwangyeongho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100996&fileSn=1
# Successfully downloaded: Gwangyeongho-fishing
# Downloading Gangnam-T--Gangnam--Cheonjeonho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100990&fileSn=1
# Successfully downloaded: Gangnam-T--Gangnam--Cheonjeonho
# Downloading Boseongho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100884&fileSn=1
# Successfully downloaded: Boseongho-fishing
# Downloading 98 Pingjinho-Dong from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100815&fileSn=1
# Successfully downloaded: 98 Pingjinho-Dong
# Downloading Seongshinho-towed-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100797&fileSn=1
# Successfully downloaded: Seongshinho-towed-fishing
# Downloading Yeongjinho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100939&fileSn=1
# Successfully downloaded: Yeongjinho-fishing
# Downloading Yoo-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100794&fileSn=1
# Successfully downloaded: Yoo-1
# Downloading Yeonggwangho-1 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100773&fileSn=1
# Successfully downloaded: Yeonggwangho-1
# Downloading Daegokho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100761&fileSn=1
# Successfully downloaded: Daegokho
# Downloading Poseidon-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100755&fileSn=1
# Successfully downloaded: Poseidon-fishing
# Downloading Dongwooho-Sierra from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100655&fileSn=1
# Successfully downloaded: Dongwooho-Sierra
# Downloading Hurricane from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100627&fileSn=1
# Successfully downloaded: Hurricane
# Downloading Oil-liquid-7 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100618&fileSn=1
# Successfully downloaded: Oil-liquid-7
# Downloading Shinsungho-Je from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100544&fileSn=1
# Successfully downloaded: Shinsungho-Je
# Downloading SS-Geoseongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100532&fileSn=1
# Successfully downloaded: SS-Geoseongho
# Downloading Gwangyang-Haedongho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100538&fileSn=1
# Successfully downloaded: Gwangyang-Haedongho
# Downloading Samyang 201 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100535&fileSn=1
# Successfully downloaded: Samyang 201
# Downloading 101 Samwooho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100541&fileSn=1
# Successfully downloaded: 101 Samwooho
# Downloading Haegumgang 2 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100361&fileSn=1
# Successfully downloaded: Haegumgang 2
# Downloading Bongjinho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100403&fileSn=1
# Successfully downloaded: Bongjinho-fishing
# Downloading Seoul-Doseon from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100332&fileSn=1
# Successfully downloaded: Seoul-Doseon
# Downloading 102 Ilgwangho-Helen from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100317&fileSn=1
# Successfully downloaded: 102 Ilgwangho-Helen
# Downloading Sindong 2 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100314&fileSn=1
# Successfully downloaded: Sindong 2
# Downloading 101 Formation-Treasure from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100308&fileSn=1
# Successfully downloaded: 101 Formation-Treasure
# Downloading Je-Winning from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100279&fileSn=1
# Successfully downloaded: Je-Winning
# Downloading Daerimho-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100231&fileSn=1
# Successfully downloaded: Daerimho-fishing
# Downloading Daemyungho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100301&fileSn=1
# Successfully downloaded: Daemyungho
# Downloading Ace-fishing from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100213&fileSn=1
# Successfully downloaded: Ace-fishing
# Downloading Mojave from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100219&fileSn=1
# Successfully downloaded: Mojave
# Downloading Taesung 2000 from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100192&fileSn=1
# Successfully downloaded: Taesung 2000
# Downloading Kingstar from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100183&fileSn=1
# Successfully downloaded: Kingstar
# Downloading Best 2-Eoyangho from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100171&fileSn=1
# Successfully downloaded: Best 2-Eoyangho
# Downloading 107 Hyodong from https://www.kmst.go.kr/web/atch/atchFileDownload.do?atchId=100165&fileSn=1
# Successfully downloaded: 107 Hyodong
